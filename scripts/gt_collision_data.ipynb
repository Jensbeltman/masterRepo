# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/home/jens/masterRepo/test/dataset/gt_coll_data.csv")

print("\nmean\n",df.groupby("datasetName").mean())
print("\nstd\n",df.groupby("datasetName").std())
# Out:
# mean
#                      dpI       nGTs  GTIndex_1  GTIndex_2  penetration
# datasetName
# Scape          9.787995  26.681992  16.791826   9.896552     0.606243
# Sileane      174.676084  92.431810  55.192000  45.452455     0.000845
#
# std
#                     dpI       nGTs  GTIndex_1  GTIndex_2  penetration
# datasetName
# Scape         7.730334  14.314508  13.091702   9.612480     0.971392
# Sileane      83.379650  41.742565  35.669952  36.413084     0.002447

# %%
df.hist("penetration",by=["datasetName","objName"],bins=100,figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'(Scape, AngleTubes)'}>,
#         <AxesSubplot:title={'center':'(Scape, Conrods)'}>,
#         <AxesSubplot:title={'center':'(Scape, Ears)'}>,
#         <AxesSubplot:title={'center':'(Scape, Gameboys)'}>],
#        [<AxesSubplot:title={'center':'(Sileane, brick)'}>,
#         <AxesSubplot:title={'center':'(Sileane, bunny)'}>,
#         <AxesSubplot:title={'center':'(Sileane, candlestick)'}>,
#         <AxesSubplot:title={'center':'(Sileane, gear)'}>],
#        [<AxesSubplot:title={'center':'(Sileane, markers_bump)'}>,
#         <AxesSubplot:title={'center':'(Sileane, markers_flat)'}>,
#         <AxesSubplot:title={'center':'(Sileane, markers_flat_simulation)'}>,
#         <AxesSubplot:title={'center':'(Sileane, pepper)'}>],
#        [<AxesSubplot:title={'center':'(Sileane, tless_20)'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
